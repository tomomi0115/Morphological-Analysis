# %% [markdown]
# <a href="https://colab.research.google.com/github/tomomi0115/Morphological-Analysis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How To Use

# %% [markdown]
# **グラフィカルにオンラインでNotebookを編集できるのでいいですよね！！！**

# %%
# コードを埋め込めるし実行もできる！！！
import torch

# %% [markdown]
# 画像も目込めます↓

# %% [markdown]
# **![コメント 2021-02-15 002015.png](data:image/png;base64,...)
